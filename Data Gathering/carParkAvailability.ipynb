# %%
import requests
import pandas as pd

def fetch_data_from_url(url):
    payload = {}
    headers = {
        'AccountKey': 'OFL+AHv4Sz2M/sMoaLpunw=='
    }

    response = requests.request("GET", url, headers=headers, data=payload)
    data = response.json()
    df = pd.DataFrame(data['value'])
    
    return df

# %%
url="http://datamall2.mytransport.sg/ltaodataservice/CarParkAvailabilityv2"
carPark=fetch_data_from_url(url)

# %%
#ERP rates for reference
url="http://datamall2.mytransport.sg/ltaodataservice/ERPRates"
erpRates=fetch_data_from_url(url)

# %%
carPark
# Out:
#     CarParkID    Area                        Development  \
# 0           1  Marina                        Suntec City
# 1           2  Marina                      Marina Square
# 2           3  Marina                       Raffles City
# 3           4  Marina                      The Esplanade
# 4           5  Marina                 Millenia Singapore
# ..        ...     ...                                ...
# 495       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 496       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 497       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 498       CAM                     BLK 88 TANGLIN HALT RD
# 499       CAM                     BLK 88 TANGLIN HALT RD
#
#                                   Location  AvailableLots LotType Agency
# 0                        1.29375 103.85718           2049       C    LTA
# 1                        1.29115 103.85728           1675       C    LTA
# ...

# %%
carPark
# Out:
#     CarParkID    Area                        Development  \
# 0           1  Marina                        Suntec City
# 1           2  Marina                      Marina Square
# 2           3  Marina                       Raffles City
# 3           4  Marina                      The Esplanade
# 4           5  Marina                 Millenia Singapore
# ..        ...     ...                                ...
# 495       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 496       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 497       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 498       CAM                     BLK 88 TANGLIN HALT RD
# 499       CAM                     BLK 88 TANGLIN HALT RD
#
#                                   Location  AvailableLots LotType Agency
# 0                        1.29375 103.85718              5       C    LTA
# 1                        1.29115 103.85728            746       C    LTA
# ...

# %%
carPark
# Out:
#     CarParkID    Area                        Development  \
# 0           1  Marina                        Suntec City
# 1           2  Marina                      Marina Square
# 2           3  Marina                       Raffles City
# 3           4  Marina                      The Esplanade
# 4           5  Marina                 Millenia Singapore
# ..        ...     ...                                ...
# 495       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 496       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 497       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 498       CAM                     BLK 88 TANGLIN HALT RD
# 499       CAM                     BLK 88 TANGLIN HALT RD
#
#                                   Location  AvailableLots LotType Agency
# 0                        1.29375 103.85718            469       C    LTA
# 1                        1.29115 103.85728            855       C    LTA
# ...

# %%
rows_with_null_area = carPark[carPark['Area'].isnull()]
rows_with_null_area
# Out:
#     CarParkID Area                            Development  \
# 42      A0007  NaN               ANGULLIA PARK OFF STREET
# 43      A0007  NaN               ANGULLIA PARK OFF STREET
# 44      A0011  NaN             ARMENIAN STREET OFF STREET
# 45      A0017  NaN  ARAB STREET - QUEEN STREET OFF STREET
# 46      A0017  NaN  ARAB STREET - QUEEN STREET OFF STREET
# ..        ...  ...                                    ...
# 495       C4M  NaN      BLK 413A COMMONWEALTH AVENUE WEST
# 496       C4M  NaN      BLK 413A COMMONWEALTH AVENUE WEST
# 497       C4M  NaN      BLK 413A COMMONWEALTH AVENUE WEST
# 498       CAM  NaN                 BLK 88 TANGLIN HALT RD
# 499       CAM  NaN                 BLK 88 TANGLIN HALT RD
#
#                                   Location  AvailableLots LotType Agency
# 42   1.3053280313212745 103.82957069514487              0       Y    URA
# 43   1.3053280313212745 103.82957069514487             35       C    URA
# ...

# %%
carPark.replace('', pd.NA, inplace=True)

# %%
carPark['Area'].value_counts()
# Out:
# Area
# Orchard               18
# Others                 9
# Marina                 7
# Harbfront              5
# JurongLakeDistrict     3
# Name: count, dtype: int64

# %%
def fetch_data_from_url(url, rows=1000):
    payload = {}
    headers = {
        'AccountKey': 'OFL+AHv4Sz2M/sMoaLpunw=='
    }

    params = {
        '$top': rows
    }

    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    df = pd.DataFrame(data['value'])
    
    return df

url = "http://datamall2.mytransport.sg/ltaodataservice/CarParkAvailabilityv2"
carPark = fetch_data_from_url(url)

# %%
carPark
# Out:
#     CarParkID    Area                        Development  \
# 0           1  Marina                        Suntec City
# 1           2  Marina                      Marina Square
# 2           3  Marina                       Raffles City
# 3           4  Marina                      The Esplanade
# 4           5  Marina                 Millenia Singapore
# ..        ...     ...                                ...
# 495       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 496       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 497       C4M          BLK 413A COMMONWEALTH AVENUE WEST
# 498       CAM                     BLK 88 TANGLIN HALT RD
# 499       CAM                     BLK 88 TANGLIN HALT RD
#
#                                   Location  AvailableLots LotType Agency
# 0                        1.29375 103.85718            303       C    LTA
# 1                        1.29115 103.85728            940       C    LTA
# ...

# %%
token="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..ffUS65pS0LDXI-qbpU9kla3x71LWc7AA0DOaaexJ7Po"

# %%
url = "https://www.onemap.gov.sg/api/public/revgeocode?location=1.3029418442251717 ,103.8570252731165&buffer=40&addressType=All&otherFeatures=N"


headers = {"Authorization": token}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    df = pd.DataFrame(data)  
else:
    print("Error:", response.status_code)

# %%
token2="pk.28b75f44ef397e930072b603213aaee1" #mylocationiq

# %%
url = "https://us1.locationiq.com/v1/reverse?lat=1.311099801941753&lon=103.83975443333466&format=json&key=pk.28b75f44ef397e930072b603213aaee1"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"place_id":"162145737","licence":"https:\/\/locationiq.com\/attribution","osm_type":"way","osm_id":"172533488","lat":"1.3108427","lon":"103.8400348","display_name":"Monk's Hill Road, Cairnhill, Newton, Singapore, Central Region, 229492, Singapore","address":{"road":"Monk's Hill Road","neighbourhood":"Cairnhill","suburb":"Newton","city":"Singapore","county":"Central Region","postcode":"229492","country":"Singapore","country_code":"sg"},"boundingbox":["1.3107979","1.3108427","103.8400348","103.840114"]}

# %%
carPark[['Latitude', 'Longitude']] = carPark['Location'].str.split(' ', expand=True)
carPark.head()
# Out:
#   CarParkID    Area         Development           Location  AvailableLots  \
# 0         1  Marina         Suntec City  1.29375 103.85718              5
# 1         2  Marina       Marina Square  1.29115 103.85728            746
# 2         3  Marina        Raffles City  1.29382 103.85319            326
# 3         4  Marina       The Esplanade  1.29011 103.85561            628
# 4         5  Marina  Millenia Singapore  1.29251 103.86009            777
#
#   LotType Agency Latitude  Longitude
# 0       C    LTA  1.29375  103.85718
# 1       C    LTA  1.29115  103.85728
# 2       C    LTA  1.29382  103.85319
# 3       C    LTA  1.29011  103.85561
# 4       C    LTA  1.29251  103.86009

# %%
import pandas as pd
import requests

def get_display_name(row, results_df, skipped_df):
    lat = row['Latitude']
    lon = row['Longitude']
    id_str = row['CarParkID']
    
    url = f"https://us1.locationiq.com/v1/reverse?lat={lat}&lon={lon}&format=json&key=pk.28b75f44ef397e930072b603213aaee1"
    headers = {"accept": "application/json"}

    response = requests.get(url, headers=headers)
    data = response.json()

    try:
        display_name = data['display_name']
        df = pd.DataFrame(row).transpose()  
        df['display_name'] = display_name
        results_df = pd.concat([results_df, df], ignore_index=True)
    except KeyError:
        skipped_df = pd.concat([skipped_df, pd.DataFrame(row).transpose()], ignore_index=True)
    
    return results_df, skipped_df

results_df = pd.DataFrame(columns=carPark.columns.tolist() + ['display_name'])
skipped_df = pd.DataFrame(columns=carPark.columns)

for index, row in carPark.iterrows():
    results_df, skipped_df = get_display_name(row, results_df, skipped_df)

# %%
len(results_df)
# Out:
# 296

# %%
len(skipped_df)
# Out:
# 204

# %%
sdf=skipped_df

# %%
import requests
import pandas as pd

def get_display_name(row, results_df):
    lat = row['Latitude']
    lon = row['Longitude']
    carpark_id = row['CarParkID']
    
    url = f"https://us1.locationiq.com/v1/reverse?lat={lat}&lon={lon}&format=json&key=pk.28b75f44ef397e930072b603213aaee1"
    headers = {"accept": "application/json"}

    response = requests.get(url, headers=headers)
    data = response.json()

    if 'display_name' in data:
        display_name = data['display_name']
    else:
        display_name = "Not found"
    row['display_name'] = display_name
    results_df = pd.concat([results_df, pd.DataFrame([row])], ignore_index=True)
    
    return results_df

final_df = pd.DataFrame(columns=['CarParkID', 'display_name', 'Latitude', 'Longitude'])

for index, row in sdf.iterrows():
    final_df = get_display_name(row, final_df)

# %%
final_df
# Out:
#     CarParkID                                       display_name  \
# 0           5  Millenia Tower, 1, Temasek Avenue, Suntec City...
# 1       A0017  Arab Street, Little India, Rochor, Singapore, ...
# 2       C0162  Fort Canning Park, Central Expressway, Museum,...
# 3       D0006  Duxton Hill Car Park, Duxton Hill, Chinatown, ...
# 4       D0026  Little India, Queen Street Terminal, Selegie, ...
# ..        ...                                                ...
# 199       BM5  8, Jalan Rumah Tinggi, Bukit Merah, Singapore,...
# 200       BM6  Blk 54, Lengkok Bahru, Bukit Merah, Singapore,...
# 201       BM6  Blk 54, Lengkok Bahru, Bukit Merah, Singapore,...
# 202       BM6  Blk 54, Lengkok Bahru, Bukit Merah, Singapore,...
# 203       C16  435, Clementi Avenue 3, Westpeak Terrace, Clem...
#
#                Latitude           Longitude    Area  \
# 0               1.29251           103.86009  Marina
# 1    1.3029418442251717   103.8570252731165
# ...

# %%
concatenated_df = pd.concat([final_df, results_df], ignore_index=True)

# %%
carPark[carPark["CarParkID"] == "D0030"]
# Out:
#    CarParkID Area         Development Location  AvailableLots LotType Agency  \
# 67     D0030       42 DEFU LANE 7 HVP                       0       H    URA
#
#    Latitude Longitude
# 67               None

# %%
concatenated_df.to_csv(r"C:\Users\vikra\Downloads\carParkLocation.csv")
